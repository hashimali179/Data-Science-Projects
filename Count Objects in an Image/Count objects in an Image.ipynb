# %%
pwd
# Out:
# 'C:\\Users\\Hashim\\Documents'

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import cvlib as cv
from cvlib.object_detection import draw_bbox
from numpy.lib.polynomial import poly
print("DONE")
# Out:
# DONE

# %%
image = cv2.imread("traffic.jpg")
box, label, count = cv.detect_common_objects(image)
output = draw_bbox(image, box, label, count)
plt.figure(figsize=(6,8))
plt.imshow(output)
plt.show()

# %%
print("Number of cars in this image are " +str(label.count('car')))
print("Number of people in this image are " +str(label.count('person')))
print("Number of bicycles in this image are " +str(label.count('bicycle')))
# Out:
# Number of cars in this image are 5
# Number of people in this image are 2
# Number of bicycles in this image are 1
